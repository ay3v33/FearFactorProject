# %%
import pandas as pd

df = pd.read_csv("../my_results.csv")
df.head()
# Out:
#                                  postId            _type  \
# 0  bcac1c71-62a6-4b13-97c4-a6c48948163a  SocialMediaPost
# 1  893b1d3f-cf96-488b-8a8b-214722074672  SocialMediaPost
# 2  d4156ff0-b5bb-44bb-b1d9-d3b47fe2c2a4  SocialMediaPost
# 3  dbce35b3-f2ca-4129-8168-0f63c0b61964  SocialMediaPost
# 4  0452d3b2-6818-424b-ad29-0648cf8c77a4  SocialMediaPost
#
#                     requestForContentId  agentId language  \
# 0  e02a7b09-8a6e-4e6d-8e6c-9164c88fe32d   IDP411  English
# 1  fd5402f5-b5d2-4b80-a849-4859abf89f75  IDP1262  English
# 2  e8cd8459-0d0d-45a7-bfc1-25c75f3f7ab7    LP962  English
# 3  c4d34d8f-5b13-4658-bce1-a072cd6d368a     LP30  English
# 4  2978df0e-ac5b-4d92-8ce2-dd14fbd5ae21  IDP1017  English
#
#                                                 text  \
# 0  8am @KilleenRegional, drones descending on us!...
# 1  Concerns rising as reports indicate drone laun...
# 2  8am at Killeen Regional Airport, drone launch ...
# ...

# %%
import random as rnd
row = rnd.randint(0, df.shape[0]-1)
print(df.iloc[row, 5])
df.iloc[row, [10, 11, 12, 13]]
# Out:
# Concern over reckless Donovian tank driver who injured a civilian in Temple, TX. A review of military policies & logistics is essential to prevent such incidents. Can we balance defense with safety?
# val_fear      0.097
# val_stress    0.113
# val_morale   -0.128
# val_trust      0.11
# Name: 1066, dtype: object

# %%
import matplotlib.pyplot as plt
df.hist()
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[26], line 1
# ----> 1 df.hist()
#
# File ~\AppData\Roaming\Python\Python310\site-packages\pandas\plotting\_core.py:250, in hist_frame(data, column, by, grid, xlabelsize, xrot, ylabelsize, yrot, ax, sharex, sharey, figsize, layout, bins, backend, legend, **kwargs)
#     145 def hist_frame(
#     146     data: DataFrame,
#     147     column: IndexLabel | None = None,
#    (...)
#     162     **kwargs,
#     163 ):
#     164     """
#     165     Make a histogram of the DataFrame's columns.
#     166
#    (...)
#     248         >>> hist = df.hist(bins=3)
#     249     """
# --> 250     plot_backend = _get_plot_backend(backend)
#     251     return plot_backend.hist_frame(
#     252         data,
#     253         column=column,
#    (...)
#     267         **kwargs,
#     268     )
#
# ...
